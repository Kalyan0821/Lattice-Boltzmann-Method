# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
f = np.loadtxt("./F.txt")
b = np.loadtxt("./B.txt")
ff = np.loadtxt("./FF.txt")
delta = np.loadtxt("./delta.txt")

r = 0.05
dx = 1/500
i0 = 100
j0 = 100

f.shape, b.shape, ff.shape, delta.shape
# Out:
# ((564, 2), (564, 2), (564, 2), (564,))

# %%
plt.figure(figsize=(7, 7))
sns.scatterplot(f[:, 0], f[:, 1])
sns.scatterplot(b[:, 0], b[:, 1])
sns.scatterplot(ff[:, 0], ff[:, 1])

plt.legend(["F", "B", "FF"])

plt.gca().add_patch(plt.Circle((100, 100), 25, color='k', fill=False))
plt.xlim(70, 130)
plt.ylim(70, 130)
# Out:
# (70, 130)

# %%
np.sum(delta==0), np.sum(delta==1)
# Out:
# (76, 84)

# %%
plt.figure(figsize=(7, 7))
sns.scatterplot(f[delta==0][:, 0], f[delta==0][:, 1])
sns.scatterplot(b[delta==0][:, 0], b[delta==0][:, 1])
# sns.scatterplot(ff[delta==0][:, 0], ff[delta==0][:, 1])
# plt.legend(["F", "B", "FF"])

plt.gca().add_patch(plt.Circle((100, 100), 25, color='k', fill=False))
plt.xlim(70, 130)
plt.ylim(70, 130)
# Out:
# (70, 130)

# %%
plt.figure(figsize=(7, 7))
sns.scatterplot(f[delta==1][:, 0], f[delta==1][:, 1])
sns.scatterplot(b[delta==1][:, 0], b[delta==1][:, 1])
# sns.scatterplot(ff[delta==1][:, 0], ff[delta==1][:, 1])

# plt.legend(["F", "B", "FF"])

plt.gca().add_patch(plt.Circle((100, 100), 25, color='k', fill=False))
plt.xlim(70, 130)
plt.ylim(70, 130)
# Out:
# (70, 130)
